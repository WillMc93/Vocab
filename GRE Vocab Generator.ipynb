# %%
import re
import sqlite3

import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Get Vocab List

# %%
# Load SQLite DB
conn = sqlite3.connect('vocab/collection.anki2')
curs = conn.cursor()
curs.execute('SELECT flds FROM notes')

words = curs.fetchall()
conn.close()

# %%
# Show what it looks like now
print(words[:5])
# Out:
# [('abbreviate [sound:abbreviate.mp3]\x1f\x1f\x1f\x1fBecause we were running out of time, the lecturer had to abbreviate her speech.\x1fshorten',), ('abate [sound:abate.mp3]\x1f\x1f\x1f\x1fRather than leaving immediately, they waited for the storm to abate.\x1fsubside or moderate',), ('abortive [sound:abortive.mp3]\x1f\x1f\x1f\x1fWe had to abandon our abortive attempts.\x1funsuccessful; fruitless',), ('absolute [sound:absolute.mp3]\x1f\x1f\x1f\x1fAlthough the King of Siam was an absolute monarch, he did not want to behead his unfaithful wife without absolute evidence of her infidelity.\x1fcomplete; totally unlimited; certain',), ('abstract\x1f/ˈæbstrækt/\x1f<span style="font-family: Georgia;font-size: 12px">&nbsp;[sound:abstract.mp3]</span>\x1fadj\x1fTo him, hunger was an abstract concept; he had never missed a meal.<div><br /></div><div>The research shows that pre-school children are capable of thinking in abstract terms.&nbsp;</div>\x1ftheoretical; not concrete; non-representational',)]

# %%
# Breakup strings for loading into dataframe
words = [tupl[0] for tupl in words] # break tuples
words = [word.split('\x1f') for word in words]

# %%
# Show the current state of the data and confirm that the data is uniform
print(words[4])

for word in words:
    assert(len(word) == 6)
# Out:
# ['abstract', '/ˈæbstrækt/', '<span style="font-family: Georgia;font-size: 12px">&nbsp;[sound:abstract.mp3]</span>', 'adj', 'To him, hunger was an abstract concept; he had never missed a meal.<div><br /></div><div>The research shows that pre-school children are capable of thinking in abstract terms.&nbsp;</div>', 'theoretical; not concrete; non-representational']

# %%
# Transfer to a DataFrame
columns = ['word', 'pronunciation', 'sound', 'part of speech', 'sentence', 'definition']
vocab = pd.DataFrame(words, columns=columns)

# %%
# Show the DataFrame
display(vocab.head())
# Out:
#                                 word pronunciation  \
# 0  abbreviate [sound:abbreviate.mp3]
# 1            abate [sound:abate.mp3]
# 2      abortive [sound:abortive.mp3]
# 3      absolute [sound:absolute.mp3]
# 4                           abstract   /ˈæbstrækt/
#
#                                                sound part of speech  \
# 0
# 1
# 2
# 3
# 4  <span style="font-family: Georgia;font-size: 1...            adj
#
#                                             sentence  \
# 0  Because we were running out of time, the lectu...
# 1  Rather than leaving immediately, they waited f...
# 2           We had to abandon our abortive attempts.
# 3  Although the King of Siam was an absolute mona...
# 4  To him, hunger was an abstract concept; he had...
#
#                                         definition
# 0                                          shorten
# 1                              subside or moderate
# 2                          unsuccessful; fruitless
# 3             complete; totally unlimited; certain
# 4  theoretical; not concrete; non-representational

# %% [markdown]
# ## Cleanup the word list

# %%
# Get rid of sound tags
re_sound = r'\[sound:.*.mp3\]'
vocab.loc[:, 'word'] = vocab['word'].str.replace(re_sound, '', regex=True)

# Get rid of '&nbsp' after word
re_stuff_after = r'\s*&nbsp.*'
vocab.loc[:, 'word'] = vocab['word'].str.replace(re_stuff_after, '', regex=True)

# Check for uniqueness
display(vocab[vocab.duplicated(subset='word', keep=False)])
# Out:
#               word      pronunciation  \
# 780   countenance        /kaʊntənəns/
# 781   countenance       /ˈkaʊntənəns/
# 1292       exploit  &nbsp;/ɪkˈsplɔɪt/
# 1293       exploit        /ɪkˈsplɔɪt/
# 1359        fester    &nbsp;/ˈfestər/
# 1360        fester          /ˈfestər/
# 1394        fleece            /fliːs/
# 1395        fleece      &nbsp;/fliːs/
# 1414          foil       &nbsp;/fɔɪl/
# 1415          foil       &nbsp;/fɔɪl/
# 1440       founder         /ˈfaʊndər/
# 1441       founder   [ˈfaʊndər]&nbsp;
# 1482          gall             /ɡɔːl/
# 1483          gall             /ɡɔːl/
# 1546         gorge           /ɡɔːrdʒ/
# 1547         gorge           /ɡɔːrdʒ/
# 1625      hermetic
# 1626      hermetic
# 2348     objective       /əbˈdʒektɪv/
# 2349     objective       /əbˈdʒektɪv/
# 2653     precedent       /ˈpresɪdənt/
# 2654     precedent       /ˈpresɪdənt/
# 2808        quarry          /ˈkwɑːri/
# 2809        quarry          /ˈkwɑːri/
# 2973       resolve         /rɪˈzɔːlv/
# 2974       resolve         /rɪˈzɔːlv/
# 3188         sloth            /sloʊθ/
# 3189         sloth            /sloʊθ/
# 3273         stint            /stɪnt/
# 3274         stint            /stɪnt/
# 3289        strut
# 3290        strut            /strʌt /
# 3591       vagrant        /'veigrənt/
# 3592       vagrant        /'veigrənt/
# 3710        welter          /ˈweltər/
# 3711        welter          /ˈweltər/
#
#                                                   sound  part of speech  \
# 780                             [sound:countenance.mp3]            verb
# 781                             [sound:countenance.mp3]            noun
# 1292  [sound:exploit verb - Definition, pictures, pr...            noun
# 1293  <span style="font-family: Georgia;font-size: 1...            verb
# 1359  [sound:fester verb - Definition, pictures, pro...            verb
# 1360  <span style="font-family: Georgia;font-size: 1...  verb - feeling
# 1394  [sound:fleece noun - Definition, pictures, pro...            noun
# 1395  [sound:fleece noun - Definition, pictures, pro...            verb
# 1414  [sound:foil noun - Definition, pictures, pronu...            noun
# 1415  [sound:foil verb - Definition, pictures, pronu...            verb
# 1440                                                               verb
# 1441                                                               noun
# 1482                             &nbsp;[sound:gall.wav]            noun
# 1483                                   [sound:gall.wav]            verb
# 1546                                  [sound:gorge.wav]            noun
# 1547                                  [sound:gorge.wav]            verb
# 1625  [sound:hermetic_adjective_Definition_pictures_...
# 1626  [sound:hermetic_adjective_Definition_pictures_...
# 2348  [sound:objective_noun_Definition_pictures_pron...             adj
# 2349  [sound:objective_noun_Definition_pictures_pron...            noun
# 2653                              [sound:precedent.mp3]             adj
# 2654                              [sound:precedent.mp3]             adj
# 2808                                 [sound:quarry.mp3]            noun
# 2809  <span style="font-family: Georgia;font-size: 1...            verb
# 2973                          &nbsp;[sound:resolve.mp3]            noun
# 2974  <span style="font-family: Georgia;font-size: 1...            verb
# 3188  <span style="font-family: Georgia;font-size: 1...            noun
# 3189                                  [sound:sloth.mp3]     noun-animal
# 3273                                  [sound:stint.wav]            verb
# 3274                                  [sound:stint.wav]            noun
# 3289
# 3290                                  [sound:strut.mp3]            noun
# 3591                          &nbsp;[sound:vagrant.mp3]             adj
# 3592  <span style="font-family: Georgia;font-size: 1...     noun-person
# 3710                                 [sound:welter.mp3]            noun
# 3711  <span style="font-family: Georgia;font-size: 1...            verb
#
#                                                sentence  \
# 780   He refused to countenance such rude behavior o...
# 781   Whe Jose saw his newborn daughter, a proud smi...
# 1292  Raoul Wallenberg was noted for his exploits in...
# 1293  Caesar Chavez fought attempts to exploit migra...
# 1359  When her finger began to fester, the doctor la...
# 1360  Joe's insult festered in Anne's mind for days,...
# 1394  They shear sheep of their fleece, which they t...
# 1395  The tricksters fleeced him of his inheritance....
# 1414  In "Star Wars," dark, evil Darth Vader is a pe...
# 1415  In the end, Skywalker is able to foil Vader's ...
# 1440  After hitting the submerged iceberg, the Titan...
# 1441  Among those drowned when the Titanic sank was ...
# 1482  The knowledge of his failure filled him with g...
# 1483  Their taunts galled him.<div><br></div><div>To...
# 1546  Terrified of heights, George could not bring h...
# 1547  The gluttonous guest gorged himself with food ...
# 1625  After these bandages are sterilized, they are ...
# 1626  It is strange to consider that modern chemistr...
# 2348  Even though he was her son, she tried to be ob...
# 2349   A degree in medicine was her ultimate objective.
# 2653  This decision sets a precedent for future case...
# 2654  Our discussions, precedent to this event, cert...
# 2808  The police closed in on their quarry.<div><br>...
# 2809  They quarried blocks of marble out of the hill...
# 2973  Nothing could shake his resolve that his child...
# 2974  Homes resolved to travel to Bohemia to resolve...
# 3188  Such sloth in a young person is deplorable; go...
# 3189  Note how well the somewhat greenish coat of th...
# 3273  Spare no expense, the bride's father said, ref...
# 3274  He performed his daily stint cheerfully and wi...
# 3289  His strut as he marched about the parade groun...
# 3290  The engineer calculated that the strut support...
# 3591  He tried to study, but could not collect his v...
# 3592  Because he was a stranger in town with no visi...
# 3710  The existing welter of overlapping federal and...
# 3711  At the height of the battle, the casualties we...
#
#                                              definition
# 780                       approve; tolerate, consent to
# 781                                                face
# 1292          deed or action, particularly a brave deed
# 1293                    make use of, sometimes unjustly
# 1359                                       generate pus
# 1360           rankle, produce irritation or resentment
# 1394                               wool coat of a sheep
# 1395  rob; plunder;&nbsp;to take a lot of money from...
# 1414                                           contrast
# 1415  defeat; frustrate;<font color="#0000ff"><b> th...
# 1440                              fail completely; sink
# 1441  person who establishes (an organization, busin...
# 1482           bitterness; nerve; impudence, resentment
# 1483  annoy; chafe;&nbsp;to make sb feel upset and a...
# 1546  narrow canyon; steep, rocky cleft;&nbsp;a deep...
# 1547  stuff oneself;&nbsp;to eat a lot of sth, until...
# 1625  sealed by fusion so as to be airtight;&nbsp;&n...
# 1626                     obscure and mysterious; occult
# 2348  not influenced by emotions; fair;&nbsp;<b><fon...
# 2349                                          goal; aim
# 2653  something preceding in time that may be used a...
# 2654                      preceding in time, rank, etc.
# 2808  victim; object of a hunt; <b><font color="#000...
# 2809                                           dig into
# 2973       determination&nbsp;[sound:determination.wav]
# 2974  decide; <b><font color="#0000ff">settle</font>...
# 3188                                           laziness
# 3189                   slow-moving tree-dwelling mammal
# 3273                             be thrifty; set limits
# 3274  supply; allotted amount; assigned portion of work
# 3289                                       pompous walk
# 3290                                     supporting bar
# 3591                               stray; random;&nbsp;
# 3592                                  homeless wanderer
# 3710  turmoil; bewildering jumble;&nbsp;a large and ...
# 3711                                             wallow

# %%
display(vocab)
# Out:
#              word pronunciation  \
# 0     abbreviate
# 1          abate
# 2       abortive
# 3       absolute
# 4        abstract   /ˈæbstrækt/
# ...           ...           ...
# 3753        zany       /ˈzeɪni/
# 3754         zeal        /ziːl/
# 3755       zealot      /ˈzelət/
# 3756       zenith      /ˈzenɪθ/
# 3757      zephyr       /ˈzefər/
#
#                                                   sound part of speech  \
# 0
# 1
# 2
# 3
# 4     <span style="font-family: Georgia;font-size: 1...            adj
# ...                                                 ...            ...
# 3753                                   [sound:zany.mp3]      adjective
# 3754  <span style="font-family: Georgia;font-size: 1...           noun
# 3755                           &nbsp;[sound:zealot.mp3]    noun-person
# 3756  <span style="font-family: Georgia;font-size: 1...           noun
# 3757                                 [sound:zephyr.mp3]           noun
#
#                                                sentence  \
# 0     Because we were running out of time, the lectu...
# 1     Rather than leaving immediately, they waited f...
# 2              We had to abandon our abortive attempts.
# 3     Although the King of Siam was an absolute mona...
# 4     To him, hunger was an abstract concept; he had...
# ...                                                 ...
# 3753  I can watch the Marx brothers' zany antics for...
# 3754  Wang's zeal was contagious; soon all his fello...
# 3755  It is good to have a few zealots in our group ...
# 3756  When the sun was at its zenith, the glare was ...
# 3757  When these zephyrs blow, it is good to be in a...
#
#                                              definition
# 0                                               shorten
# 1                                   subside or moderate
# 2                               unsuccessful; fruitless
# 3                  complete; totally unlimited; certain
# 4       theoretical; not concrete; non-representational
# ...                                                 ...
# 3753  crazy; comic,<b><font color="#0000ff"> wacky</...
# 3754                                   eager enthusiasm
# 3755  <b><font color="#0000ff">fanatic</font></b>; p...
# 3756         point directly overhead in the sky; summit
# 3757       gentle breeze; west wind, a soft gentle wind
#
# [3758 rows x 6 columns]
